# %%
pip install yfinance
# Out:
# Collecting yfinanceNote: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# conda-repo-cli 1.0.20 requires clyent==1.2.1, but you have clyent 1.2.2 which is incompatible.
# conda-repo-cli 1.0.20 requires nbformat==5.4.0, but you have nbformat 5.5.0 which is incompatible.
#   Downloading yfinance-0.2.22-py2.py3-none-any.whl (63 kB)
#      ---------------------------------------- 63.2/63.2 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: appdirs>=1.4.4 in c:\users\fr. arockia\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Collecting html5lib>=1.1
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      -------------------------------------- 112.2/112.2 kB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=4.9.1 in c:\users\fr. arockia\anaconda3\lib\site-packages (from yfinance) (4.9.1)
# Requirement already satisfied: requests>=2.26 in c:\users\fr. arockia\anaconda3\lib\site-packages (from yfinance) (2.28.1)
# Collecting pytz>=2022.5
#   Downloading pytz-2023.3-py2.py3-none-any.whl (502 kB)
#      -------------------------------------- 502.3/502.3 kB 6.3 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\fr. arockia\anaconda3\lib\site-packages (from yfinance) (4.11.1)
# Collecting multitasking>=0.0.7
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Collecting frozendict>=2.3.4
#   Downloading frozendict-2.3.8-cp39-cp39-win_amd64.whl (35 kB)
# Requirement already satisfied: pandas>=1.3.0 in c:\users\fr. arockia\anaconda3\lib\site-packages (from yfinance) (1.4.4)
# Requirement already satisfied: numpy>=1.16.5 in c:\users\fr. arockia\anaconda3\lib\site-packages (from yfinance) (1.21.5)
# Requirement already satisfied: soupsieve>1.2 in c:\users\fr. arockia\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.1)
# Requirement already satisfied: six>=1.9 in c:\users\fr. arockia\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in c:\users\fr. arockia\anaconda3\lib\site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\fr. arockia\anaconda3\lib\site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\fr. arockia\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fr. arockia\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fr. arockia\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\fr. arockia\anaconda3\lib\site-packages (from requests>=2.26->yfinance) (2.0.4)
# Installing collected packages: pytz, multitasking, html5lib, frozendict, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Uninstalling pytz-2022.1:
#       Successfully uninstalled pytz-2022.1
# Successfully installed frozendict-2.3.8 html5lib-1.1 multitasking-0.0.11 pytz-2023.3 yfinance-0.2.22

# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib as mpl
import scipy.stats as si

# %%
data = yf.download("ETH-USD", start="2021-01-01", end="2022-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                    Open         High         Low        Close    Adj Close  \
# Date
# 2021-01-01   737.708374   749.201843  719.792236   730.367554   730.367554
# 2021-01-02   730.402649   786.798462  718.109497   774.534973   774.534973
# 2021-01-03   774.511841  1006.565002  771.561646   975.507690   975.507690
# 2021-01-04   977.058838  1153.189209  912.305359  1040.233032  1040.233032
# 2021-01-05  1041.498779  1129.371460  986.811279  1100.006104  1100.006104
#
#                  Volume
# Date
# 2021-01-01  13652004358
# 2021-01-02  19740771179
# 2021-01-03  45200463368
# 2021-01-04  56945985763
# 2021-01-05  41535932781

# %%
data.tail()
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-12-27  4064.746338  4126.001465  4033.492432  4037.547607  4037.547607
# 2021-12-28  4037.538086  4037.538086  3769.280029  3800.893066  3800.893066
# 2021-12-29  3797.436279  3827.981934  3612.795898  3628.531738  3628.531738
# 2021-12-30  3632.219727  3767.559814  3595.204834  3713.852051  3713.852051
# 2021-12-31  3713.430176  3807.288818  3636.869873  3682.632812  3682.632812
#
#                  Volume
# Date
# 2021-12-27  11424360002
# 2021-12-28  17299472803
# 2021-12-29  15722555672
# 2021-12-30  12925377999
# 2021-12-31  14157285268

# %%
initial_data.plot(figsize=(10, 12), subplots=True)
# Out:
# array([<AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>,
#        <AxesSubplot:xlabel='Date'>, <AxesSubplot:xlabel='Date'>],
#       dtype=object)

# %%
data = yf.download("ETH-USD", start="2021-10-01", end="2022-01-01")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
log_return = np.log(data['Adj Close'] / data['Adj Close'].shift(1))

# %%
vol = np.sqrt(365) * log_return.std()
print('The annualised volatility is', round(vol*100,2), '%')
# Out:
# The annualised volatility is 68.16 %

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as si
import yfinance as yf

# %% [markdown]
# ## The Black Scholes Model

# %%
def euro_option_bs(S, K, T, r, vol, payoff):
    
    
    d1 = (np.log(S / K) + (r + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    d2 = (np.log(S / K) + (r - 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    if payoff == "call":
        option_value = S * si.norm.cdf(d1, 0.0, 1.0) - K * np.exp(-r * T) * si.norm.cdf(d2, 0.0, 1.0)
    elif payoff == "put":
        option_value = - S * si.norm.cdf(-d1, 0.0, 1.0) + K * np.exp(-r * T) * si.norm.cdf(-d2, 0.0, 1.0)
    
    return option_value

# %%
S = 0.25
K = 0.35
T = 0.25   # 3 Months time period
r = 0.03
q = 0

# %%
euro_option_bs(S, K, T, r, vol, 'call')
# Out:
# 0.008855531823275767

# %%
S = np.linspace(0.1,0.35,11)
cp = np.zeros((len(S),1))
for i in range(len(S)):
    cp[i] = euro_option_bs(S[i], 0.35, 0.25, 0.03, 1.56, 'call')

# %%
fig = plt.figure()
plt.plot(S, cp, '-')
plt.plot(S, np.maximum(S-0.21,0), '--')
plt.xlabel('price of cryptocurrency')
plt.ylabel('Price')
plt.title('European Call')
plt.legend(['Option Price','Payoff at T'])

# %% [markdown]
# ## Monte Carlo Simulation

# %%
def mcs_simulation_np(p):
    M = p
    I = p
    dt = T / M 
    S = np.zeros((M + 1, I))
    S[0] = S0 
    rn = np.random.standard_normal(S.shape) 
    for t in range(1, M + 1): 
        S[t] = S[t-1] * np.exp((r - vol ** 2 / 2) * dt + vol * np.sqrt(dt) * rn[t]) 
    return S

# %%
T = 0.25
r = 0.03
vol = 0.68
S0 = 36.82
K = 39

# %%
S = mcs_simulation_np(1000)

# %%
S = np.transpose(S)
S
# Out:
# array([[36.82      , 36.60489027, 36.76652368, ..., 34.82494619,
#         34.40314128, 34.45191676],
#        [36.82      , 36.03656749, 36.68031467, ..., 40.65796464,
#         40.39318643, 40.29707791],
#        [36.82      , 36.74218907, 37.12908001, ..., 22.61267014,
#         22.98736612, 23.12388034],
#        ...,
#        [36.82      , 36.95449535, 36.89458961, ..., 45.92852633,
#         45.34366788, 45.65786365],
#        [36.82      , 36.28898481, 35.97271556, ..., 23.05217127,
#         23.19415016, 23.23131828],
#        [36.82      , 37.49361657, 37.1363633 , ..., 30.67765182,
#         30.35239892, 31.34155848]])

# %%
import matplotlib.pyplot as plt
n, bins, patches = plt.hist(x=S[:,-1], bins='auto', color='#0504aa',alpha=0.9, rwidth=0.85)

plt.grid(axis='y', alpha=0.9)
plt.xlabel('S_T')
plt.ylabel('Frequency')
plt.title('Frequency distribution of the simulated end-of-preiod values')
# Out:
# Text(0.5, 1.0, 'Frequency distribution of the simulated end-of-preiod values')

# %%
c = np.mean(np.maximum(S[:,-1] - K,0))
print('European call', str(c))
# Out:
# European call 4.020854796277175

# %% [markdown]
# ## Calculating greeks for risk management

# %%
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# # #Greeks
# 1) Delta

# %%
def delta(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    d2 = (np.log(S / K) + (r - q - 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    if payoff == "call":
        delta = np.exp(- q * T) * si.norm.cdf(d1, 0.0, 1.0)
    elif payoff == "put":
        delta =  - np.exp(- q * T) * si.norm.cdf(- d1, 0.0, 1.0)
    
    return delta

# %%
S = np.linspace(0.10, 0.50, 30)
T = np.linspace(0.10, 0.7, 30)
Delta = np.zeros((len(T),len(S)))
for j in range(len(S)):
    for i in range(len(T)):
        Delta[i,j] = delta(S[j], 0.35, T[i], 0.03, 0, 0.68, 'call')

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
S, T = np.meshgrid(S, T)
surf = ax.plot_surface(S, T, Delta, rstride=2, cstride=2, cmap=plt.cm.coolwarm, linewidth=0.5, antialiased=True)
ax.set_xlabel('price of cryptocurrency')
ax.set_ylabel('Time to Expiry')
ax.set_zlabel('Delta')
fig.colorbar(surf, shrink=0.5, aspect=5);
# Out:
# C:\Users\Fr. Arockia\AppData\Local\Temp\ipykernel_14692\3601117308.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
d = delta(36.82, 39, 0.25, 0.03, 0, 0.68, 'call')
print('The value of Delta is', d.round(4),'.','If the stock price increase 1 dollar, then the value of the option will increase $', d.round(4), '.')
# Out:
# The value of Delta is 0.5091 . If the stock price increase 1 dollar, then the value of the option will increase $ 0.5091 .

# %% [markdown]
# ## 2) Gamma

# %%
def gamma(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    gamma = np.exp(- r * T) * si.norm.pdf(d1, 0.0, 1.0) / (vol * S * np.sqrt(T))
    
    return gamma

# %%
S = np.linspace(0.10, 0.35, 50)
T = np.linspace(0.10, 0.50, 50)
Gamma = np.zeros((len(T),len(S)))
for j in range(len(S)):
    for i in range(len(T)):
        Gamma[i,j] = gamma(S[j], 0.35, T[i], 0.03, 0, 0.68, 'call')

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
S, T = np.meshgrid(S, T)
surf = ax.plot_surface(S, T, Gamma, rstride=2, cstride=2, cmap=plt.cm.coolwarm, linewidth=0.5, antialiased=True)
ax.set_xlabel('Price of cryptocurrency')
ax.set_ylabel('Time to Expiry')
ax.set_zlabel('Gamma')
fig.colorbar(surf, shrink=0.5, aspect=5);
# Out:
# C:\Users\Fr. Arockia\AppData\Local\Temp\ipykernel_14692\3894109105.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
def gamma(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    gamma = np.exp(- q * T) * si.norm.pdf(d1, 0.0, 1.0) / (vol * S * np.sqrt(T))
    
    return gamma

# %%
gamma(36.82, 39, 0.25, 0.03, 0, 0.68, 'call')
# Out:
# 0.031859112949562396

# %% [markdown]
# ## 3) Speed

# %%
def speed(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    speed = - np.exp(- q * T) * si.norm.pdf(d1, 0.0, 1.0) / ((vol **2) * (S**2) * np.sqrt(T)) * (d1 + vol * np.sqrt(T))
    
    return speed

# %%
S = np.linspace(0.10, 0.35, 50)
T = np.linspace(0.10, 0.50, 50)
Speed = np.zeros((len(T),len(S)))
for j in range(len(S)):
    for i in range(len(T)):
        Speed[i,j] = speed(S[j], 0.35, T[i], 0.03, 0, 0.68, 'call')

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
S, T = np.meshgrid(S, T)
surf = ax.plot_surface(S, T, Speed, rstride=2, cstride=2, cmap=plt.cm.coolwarm, linewidth=0.5, antialiased=True)
ax.set_xlabel('Price of Cryptocurrency')
ax.set_ylabel('Time to Expiry')
ax.set_zlabel('Speed')
fig.colorbar(surf, shrink=0.5, aspect=5);
# Out:
# C:\Users\Fr. Arockia\AppData\Local\Temp\ipykernel_14692\3090571425.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
speed(36.82, 39, 0.25, 0.03, 0, 0.68, 'call')
# Out:
# -0.0004617481627149005

# %% [markdown]
# ## 4) Theta

# %%
def theta(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    d2 = (np.log(S / K) + (r - q - 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    if payoff == "call":
        theta = vol * S * np.exp(- q * T) * si.norm.pdf(d1, 0.0, 1.0) / (2 * np.sqrt(T)) - q * S * np.exp(-q * T) * si.norm.cdf(d1, 0.0, 1.0) + r * K * np.exp(-r * T) * si.norm.cdf(d2, 0.0, 1.0)
    elif payoff == "put":
        theta = vol * S * np.exp(- q * T) * si.norm.pdf(-d1, 0.0, 1.0) / (2 * np.sqrt(T)) + q * S * np.exp(-q * T) * si.norm.cdf(-d1, 0.0, 1.0) - r * K * np.exp(-r * T) * si.norm.cdf(-d2, 0.0, 1.0)
    
    return theta

# %%
S = np.linspace(0.10, 0.35, 50)
T = np.linspace(0.10, 0.50, 50)
Theta = np.zeros((len(T),len(S)))
for j in range(len(S)):
    for i in range(len(T)):
        Theta[i,j] = theta(S[j], 0.35, T[i], 0.03, 0, 0.68, 'call')

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
S, T = np.meshgrid(S, T)
surf = ax.plot_surface(S, T, Theta, rstride=2, cstride=2, cmap=plt.cm.coolwarm, linewidth=0.5, antialiased=True)
ax.set_xlabel('Price of cryptocurrency')
ax.set_ylabel('Time to Expiry')
ax.set_zlabel('Theta')
fig.colorbar(surf, shrink=0.5, aspect=5);
# Out:
# C:\Users\Fr. Arockia\AppData\Local\Temp\ipykernel_14692\1244808799.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
theta(36.82, 39, 0.25, 0.03, 0, 0.68, 'call')
# Out:
# 10.422084198388175

# %% [markdown]
# ## 5) Rho

# %%
def rho(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    d2 = (np.log(S / K) + (r - q - 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    if payoff == "call":
        rho =  K * T * np.exp(-r * T) * si.norm.cdf(d2, 0.0, 1.0)
    elif payoff == "put":
        rho = - K * T * np.exp(-r * T) * si.norm.cdf(-d2, 0.0, 1.0)
    
    return rho

# %%
S = np.linspace(0.1, 0.35, 50)
T = np.linspace(0.1, 0.50, 50)
Rho = np.zeros((len(T),len(S)))
for j in range(len(S)):
    for i in range(len(T)):
        Rho[i,j] = rho(S[j], 0.35, T[i], 0.03, 0, 0.68, 'call')

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
S, T = np.meshgrid(S, T)
surf = ax.plot_surface(S, T, Rho, rstride=2, cstride=2, cmap=plt.cm.coolwarm, linewidth=0.5, antialiased=True)
ax.set_xlabel('Price of Cryptocurrency')
ax.set_ylabel('Time to Expiry')
ax.set_zlabel('Rho')
fig.colorbar(surf, shrink=0.5, aspect=5);
# Out:
# C:\Users\Fr. Arockia\AppData\Local\Temp\ipykernel_14692\3951647113.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
rho(36.82, 39, 0.25, 0.03, 0, 0.68, 'call')
# Out:
# 3.63451095756313

# %% [markdown]
# ## 6) Vega

# %%
def vega(S, K, T, r, q, vol, payoff):
    
    d1 = (np.log(S / K) + (r - q + 0.5 * vol ** 2) * T) / (vol * np.sqrt(T))
    vega = S * np.sqrt(T) * np.exp(-q * T) * si.norm.pdf(d1, 0.0, 1.0)
    
    return vega

# %%
S = np.linspace(0.25, 0.35, 50)
T = np.linspace(0.1, 0.50, 50)
Vega = np.zeros((len(T),len(S)))
for j in range(len(S)):
    for i in range(len(T)):
        Vega[i,j] = vega(S[j], 0.35, T[i], 0.03, 0, 0.68, 'call')

# %%
fig = plt.figure(figsize=(10, 6))
ax = fig.gca(projection='3d')
S, T = np.meshgrid(S, T)
surf = ax.plot_surface(S, T, Vega, rstride=2, cstride=2, cmap=plt.cm.coolwarm, linewidth=0.5, antialiased=True)
ax.set_xlabel('price of cryptocurrency')
ax.set_ylabel('Time to Expiry')
ax.set_zlabel('Vega')
fig.colorbar(surf, shrink=0.5, aspect=5);
# Out:
# C:\Users\Fr. Arockia\AppData\Local\Temp\ipykernel_14692\2255444555.py:2: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')

# %%
v = vega(36.82, 39, 0.25, 0.03, 0, 0.68, 'call')
print('The value of Vega is', v.round(4),'.','If the volatility increases 1%, then the value of the option will increase $', v.round(4)*0.01, '.')
# Out:
# The value of Vega is 7.3426 . If the volatility increases 1%, then the value of the option will increase $ 0.073426 .
